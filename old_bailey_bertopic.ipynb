# %% [markdown]
# <a href="https://colab.research.google.com/github/hunterwyork/CHAIN_IHME_under5_sysreview/blob/master/old_bailey_bertopic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Old Bailey Archive - PunishmentSummaries
#
# At the end of each session in the 1700s, all of the punishments from the proceeding trials of the day are read aloud. These form separate instances in the old bailey archives and are rather easy to pull out (as opposed to trying to parse within each trial what the punishment is).
#
# However, since they are read aloud all at once, it is difficult to connect them to their corresponding offenses. While this certainly can be done, I'm just going to do a simple analysis to begin with on all the punishments at once.
#
# Below is a simple graph showing the distribution of punishments by type of crime for this time period. I'll extend to 1900 once the data is done extracting, but sadly my scraping code is a little slow.
# ![Rplot.png](data:image/png;base64,...)

# %%
# %%capture
#!pip install bertopic

# %%
import pandas as pd
#trials_df = pd.read_csv("/content/drive/MyDrive/first_500_trials_pun.csv")
#trials_df2 = pd.read_csv("/content/drive/MyDrive/second_500_trials_pun.csv")
trials_df = pd.read_csv("/content/drive/MyDrive/first_1000_appended.csv")
#trials_df.append(trials_df2,ignore_index=True)
#trials_df2

# %%
temp = trials_df[trials_df['type'] == "punishmentSummary"]
import numpy as np
a = [int(str(x)[0:4]) for x in temp['date']]
import matplotlib.pyplot as plt

_ = plt.hist(a, bins='auto')  # arguments are passed to np.histogram

plt.title("Distribution of punishment summaries")

plt.show()

# %%
temp = trials_df[trials_df['type'] == "punishmentSummary"]
temp = temp.reset_index(drop=True)

paragraphs = temp['text'].values.tolist()

# %% [markdown]
# ## Regularizing Early Modern English
#
# I found a package that regularizes irregular spellings. See github for info.

# %%
# !pip install git+https://github.com/jrladd/regularize.git
# Out:
# Collecting git+https://github.com/jrladd/regularize.git
#   Cloning https://github.com/jrladd/regularize.git to /tmp/pip-req-build-_vq3fa_y
#   Running command git clone -q https://github.com/jrladd/regularize.git /tmp/pip-req-build-_vq3fa_y
# Requirement already satisfied (use --upgrade to upgrade): regularize==0.5 from git+https://github.com/jrladd/regularize.git in /usr/local/lib/python3.7/dist-packages
# Building wheels for collected packages: regularize
#   Building wheel for regularize (setup.py) ... done
#   Created wheel for regularize: filename=regularize-0.5-cp37-none-any.whl size=3491848 sha256=407f3c93ea8a24c757e66e05ac2a9c4e70d8cef9837f89d6c845883ae2f47798
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_rode4sv/wheels/cf/6b/bb/dd7d90a2012b5c9c5d5135673a958fc23b12c47536103e7341
# Successfully built regularize

# %%
from regularize import regularize as reg
paragraphs = [reg.modernize(item) for item in paragraphs]

paragraphs[0:9]
# Out:
# ["The Trials being over the Court proceeded to give Judgement as follows: Received Sentence of Death,5. Edward Williams , Benjamin Tyser , Marry Price , George Chambers , Elizabeth Cave . Burned in the Hand,2. James Quinn and Thomas Abnett To be Transported,19. Thomas Harris , Katherine Roffe , Marry Wade , John Mills William Ward , William Wellington , Thomas Free , Benjamim Brand , Bridget Noland , Susan Chapman , Sarah Morgan , Marry Wilson , John Long , John Master's , Thomas Booth , Philip Goodson , Ann Thomas , James Dillon , Marry Wright . Dorothy Crier , to be Whipped. Roberst Harrison, Fined 20 Marks,6 Months Imprisonment, and to stand in the Pillory. John Collet , Fined 20 S.",
#  'The Trials being over, the Court proceeded to give Judgement as follows: Received Sentence of Death,10. Simon Aylmore , Abraham Wood , Margaret Chapman , Henry Broom , Richard Williams , Stephen Margrove , John Wood , Ruth Licence , Eleanor Bridges , and J - M -. To be Transported,15. John Low , Katharine Davis , Stephen Clarke , Hannah Tylor , Robert Morgan , Edward Whippy , Marry Hutchins , Margaret Johnson , Frances Sunderland , Dorothy Henley , Marry Mims , William Thompson , Benjamin Larkin , Richard Wales , and John Adsey . Burned in the Hand, William Gibbs , Sarah Scott alias Bridgeway, and Thomas Launder , who lay since last Sessions. Margaret Chapman , Ruth Licence and Eleanor Bridges pleaded their Bellies, and a Jury of Matrons being impaneled, found Margaret Chapman and Eleanor Bridges with Quick Child; but Ruth Licence Not.',
#  "The Trials being over, the Court proceeded to give Judgement as followith: Received Sentence of Death,10. Marry Beal , Sarah Booker , Marry Wood , Marry Molloy , William Johnson , Charles Hurst , William Campbell , George Cap , William Hale , and Joseph Laurence , Burned in the Hand,2. Samuel Harrison , and Elizabeth Dary . To be Transported,29. Patrick Evans , John Hutchings , John Taylor , William Perry , William Gossage , Robert Godfrey , James Kettle , William Gregory , John Sowden , Robert Nelson , John Wier , Urphane Mackhoule , Elizabeth Currey , Thomas Nelson , Marry Smith , Edward Swinney , John Frost , Sarah Davis , Joseph Castle , Darby Bryan , Marthan Wood , John Birch , Marthan Mackoy alias Lewis, Joseph Winterbottom , Charles Forster , Elizabeth Dawson , John Randal , John Steel , and Susannah Cook . John Humphreys who was found Guilty of two Indictments, is to stand twice in the Pillory and to suffer twelve Months Imprisonment. Samuel Baines , George Picket , and Thomas Hardy are to stand once in the Pillory and suffer 3 Months Imprisonment. And, Charles Child to suffer Three Months Imprisonment. Marry Beal , Sarah Booker , Marry Wood , and Marry Molloy . Pleaded their Bellies; and a Jury of Matrons being impaneled, found Marry Beal , Marry Wood , and Marry Molloy with Quick Child ; but Sarah Booker not John Mills , who was formerly condernned for selling Counterfeit Stamp Paper, knowing it to be Counterfeit, pleaded his Majesty's most Gracious Pardon."]

# %% [markdown]
# Some punishment summaries are rather long. It is an option to split them up by sentences.

# %%
# Load the regular expression library
import re# Remove punctuation
paragraphs_clean = [x.lower() for x in paragraphs]
paragraphs_clean = [re.sub('[0-9]', '', x) for x in paragraphs_clean]# Convert the titles to lowercase

# !pip install embedded_topic_model
def convert(lst):
    return (lst.split("."))

sentences = [convert(lst) for lst in paragraphs_clean]

flat_sentences = [item for sublist in sentences for item in sublist]



flat_sentences = [re.sub('[,\.!?]', '', x) for x in flat_sentences]# Convert the titles to lowercase

# %%
# NLTK Stop words
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(["the", "trial","trials","being","ended", "court", "proceeded","to",
                   "give", "judgement", "as", "follows", "follow", "received", "sentence", "of"])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Try Bert-contextualized embeddings
#
# This method doesn't like proper names and numbers. First step is to replace those with the tokens "person" and "cardinal."

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
nlps = [nlp(x) for x in flat_sentences]

# %%
def no_namer(doc):
  text_no_namedentities = ""
  for chunk in doc:
      if (chunk.ent_type_ != "PERSON") & (chunk.ent_type_ != "CARDINAL"):
          text_no_namedentities += chunk.text
          if chunk.whitespace_:
                  text_no_namedentities += " "
      elif chunk.ent_type_ == "PERSON":
          text_no_namedentities += "person"
          if chunk.whitespace_:
                  text_no_namedentities += " "
      elif chunk.ent_type_ == "CARDINAL":
          text_no_namedentities += "cardinal"
          if chunk.whitespace_:
                  text_no_namedentities += " "
  return text_no_namedentities
print([no_namer(x) for x in nlps[1:5]])
print(flat_sentences[1:5])

flat_sentences_arch = flat_sentences.copy
flat_sentences = [no_namer(x) for x in nlps]
flat_sentences[1:10]
# Out:
# [' person person  person person  marry price  person person  person cave ', ' burned in the hand', ' person person and person person to be transported', ' person person  person person  person person  person person person person  person person  person free  benjamim brand  bridget noland  person person  person person  person person  person person  person personperson  person booth  person person  person person  person person  person person ']
# [' edward williams  benjamin tyser  marry price  george chambers  elizabeth cave ', ' burned in the hand', ' james quinn and thomas abnett to be transported', " thomas harris  katherine roffe  marry wade  john mills william ward  william wellington  thomas free  benjamim brand  bridget noland  susan chapman  sarah morgan  marry wilson  john long  john master's  thomas booth  philip goodson  ann thomas  james dillon  marry wright "]
# [' person person  person person  marry price  person person  person cave ',
#  ' burned in the hand',
#  ' person person and person person to be transported',
#  ' person person  person person  person person  person person person person  person person  person free  benjamim brand  bridget noland  person person  person person  person person  person person  person personperson  person booth  person person  person person  person person  person person ',
#  ' dorothy crier  to be whipped',
#  ' roberst harrison fined  marks months imprisonment and to stand in the pillory',
#  ' person person  fined  s',
#  '',
#  'the trials being over the court proceeded to give judgement as follows: received sentence or death person person  person person  person person alias filewood']

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

vectorizer_model = CountVectorizer(ngram_range=(1,1), stop_words=stop_words)
topic_model = BERTopic(vectorizer_model=vectorizer_model, nr_topics=90)
topics, _ = topic_model.fit_transform(flat_sentences)

# %%
fig = topic_model.visualize_topics(); fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="3af5957d-9c58-4954-a419-432e6ec9e0b0" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3af5957d-9c58-4954-a419-432e6ec9e0b0")) {                    Plotly.newPlot(                        "3af5957d-9c58-4954-a419-432e6ec9e0b0",                        [{"customdata": [[0.7938994765281677, 6.50770378112793, 0, "col | chap | syprus | cham | prestoe", 1200], [-7.127518653869629, 16.398887634277344, 1, "marthan | ann | marry | eleanor | esther", 448], [3.6854512691497803, 2.435408115386963, 2, "muslin | fayler | ladine | watmore | olding", 448], [2.8711307048797607, -11.377927780151367, 3, "death | judgements | fear | fayler | fears", 265], [22.169097900390625, 6.025240898132324, 4, "newgate | confined | correction | twelve | fined", 256], [-5.1027679443359375, 3.652991771697998, 5, "marry | jones | riley | barnard | smith", 254], [0.9420105814933777, 4.755784511566162, 6, "executed | tyburn | convicted | sessions | july", 215], [6.295604705810547, 18.30615997314453, 7, "judges | case | indictment | prisoner | witness", 205], [12.875718116760254, 2.7789876461029053, 8, "river | whipped | steward | flood | gough", 187], [12.75745964050293, 3.450944185256958, 9, "imprisonment | suffer | prisoner | security | imprisoned", 186], [22.2900333404541, 5.759120941162109, 10, "fined | heart | barbary | axtead | timperly", 168], [1.6316032409667969, 6.062748908996582, 11, "whipped | maccullough | faucett | faulkner | fayler", 164], [-4.791921138763428, 3.9634194374084473, 12, "alias | fined | dean | pay | gardener", 162], [-5.009725570678711, 3.745002031326294, 13, "eliz | evan | transportation | ryland | gahagan", 153], [6.295718669891357, 18.306018829345703, 14, "mercy | lordship | lord | majestys | shall", 147], [1.160137414932251, 6.364980220794678, 15, "burned | hand | burn | hands | sparks", 146], [-1.5873205661773682, -5.28378438949585, 16, "john | william | thomas | james | george", 143], [-4.6628875732421875, 4.091881275177002, 17, "sheffield | yards | near | chambers | field", 142], [12.343019485473633, 4.329843521118164, 18, "navigation | transportation | imprisoned | months | fault", 140], [-5.256683349609375, 3.4985530376434326, 19, "branded | videlicet | newgate | simmonds | ruglass", 140], [22.846574783325195, 4.645075798034668, 20, "transportation | seven | imprisoned | aswell | transported", 135], [3.53788685798645, 2.318190813064575, 21, "benj | parminter | hewit | alloway | morse", 130], [0.5967207551002502, 6.281371116638184, 22, "whipped | play | elizabeth | francis | burned", 127], [11.71717643737793, 4.1962571144104, 23, "swawbrook | sykes | fayler | fear | fears", 119], [12.418868064880371, 4.2008957862854, 24, "brown | transportation | persontransportation | fined | imprisoned", 113], [22.194860458374023, 5.624414920806885, 25, "labour | hard | river | thames | work", 96], [-1.6128513813018799, -5.257853031158447, 26, "personperson | thomas | charles | william | john", 96], [-4.221400737762451, -4.45693302154541, 27, "ann | margaret | eleanor | catherine | isabella", 93], [0.02451403997838497, 6.873854160308838, 28, "convicts | convict | convicted | cardinal | acquitted", 92], [2.691166400909424, -11.557721138000488, 29, "death | attained | mayoralty | died | felony", 90], [1.0076638460159302, 5.647358417510986, 30, "discharged | proclamation | acquitted | committed | prisoners", 89], [12.667335510253906, 5.1110520362854, 31, "correction | confined | fined | corrections | improvement", 85], [21.51274299621582, 4.179305076599121, 32, "africa | transported | sentenced | appoint | seas", 81], [1.0048259496688843, 6.308450698852539, 33, "cardinal | videlicet | cath | favour | favourable", 79], [12.094456672668457, 4.58257007598876 ...

# %%
timestamps = [temp['date'][n] for n in range(len(sentences)) for k in range(len(sentences[n]))]

# %%
tops_by_time = topic_model.topics_over_time(docs=flat_sentences, 
                                                topics=topics, 
                                                timestamps = timestamps, 
                                                nr_bins = 5,
                                                global_tuning=True,
                                            evolution_tuning = True,
                                            datetime_format = "%Y%m%d")

# %%
topics = np.unique(np.reshape(np.array([topic_model.find_topics(x)[0] for x in ["prison", "whip","whipping", "imprison", "jailed", 
                                                                                "sentence","hanged", "death","hang", "jail",
                                                                                "execute", "executed"]]), newshape = -1))
topics = topics.tolist()
topic_model.visualize_topics_over_time(tops_by_time, topics = topics)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="7f47994a-2c37-4374-b2f0-78f77b2248c5" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f47994a-2c37-4374-b2f0-78f77b2248c5")) {                    Plotly.newPlot(                        "7f47994a-2c37-4374-b2f0-78f77b2248c5",                        [{"hoverinfo": "text", "hovertext": ["<b>Topic -1</b><br>Words: imprisonment, ibid, stolen, isabel, convicted", "<b>Topic -1</b><br>Words: majestys, stealing, susannah, pardon, personperson", "<b>Topic -1</b><br>Words: convicted, majestys, moses, former, prisoners", "<b>Topic -1</b><br>Words: jail, personperson, stolen, lives, goods", "<b>Topic -1</b><br>Words: hoods, prisoners, worth, hood, benefit"], "marker": {"color": "#E69F00"}, "mode": "lines", "name": "-1_majestys_prisoners_convicted_read", "type": "scatter", "x": [17179569.304, 17408648.2, 17636587.4, 17864526.6, 18092465.8], "y": [294, 314, 521, 406, 30]}, {"hoverinfo": "text", "hovertext": ["<b>Topic 3</b><br>Words: death, none, judgements, fear, fayler", "<b>Topic 3</b><br>Words: death, judgements, fear, fayler, fears", "<b>Topic 3</b><br>Words: death, judgements, fear, fayler, fears", "<b>Topic 3</b><br>Words: death, judgements, fear, fayler, fears"], "marker": {"color": "#56B4E9"}, "mode": "lines", "name": "3_death_judgements_fear_fayler", "type": "scatter", "x": [17179569.304, 17408648.2, 17636587.4, 17864526.6], "y": [85, 88, 90, 2]}, {"hoverinfo": "text", "hovertext": ["<b>Topic 6</b><br>Words: execution, sentenced, burned, sledge, executed", "<b>Topic 6</b><br>Words: executed, convicted, october, july, april", "<b>Topic 6</b><br>Words: executed, tyburn, convicted, july, sessions", "<b>Topic 6</b><br>Words: executed, arson, burning, counts, remanded"], "marker": {"color": "#009E73"}, "mode": "lines", "name": "6_executed_tyburn_convicted_sessions", "type": "scatter", "x": [17179569.304, 17408648.2, 17636587.4, 17864526.6], "y": [6, 71, 130, 8]}, {"hoverinfo": "text", "hovertext": ["<b>Topic 7</b><br>Words: prosecuted, proceedings, prosecute, indicted, promissory", "<b>Topic 7</b><br>Words: goods, stealing, stolen, branding, larcenies", "<b>Topic 7</b><br>Words: judges, case, cardinal, indictment, declared", "<b>Topic 7</b><br>Words: case, indictment, judges, prisoner, felony", "<b>Topic 7</b><br>Words: witness, judges, prisoner, case, prove"], "marker": {"color": "#F0E442"}, "mode": "lines", "name": "7_judges_case_indictment_prisoner", "type": "scatter", "x": [17179569.304, 17408648.2, 17636587.4, 17864526.6, 18092465.8], "y": [11, 9, 24, 107, 54]}, {"hoverinfo": "text", "hovertext": ["<b>Topic 8</b><br>Words: katharine, flood, countess, picken, shaccoy", "<b>Topic 8</b><br>Words: whipped, gough, cassells, shoot, locher", "<b>Topic 8</b><br>Words: river, steward, respited, six, whipped", "<b>Topic 8</b><br>Words: bets, vallence, boutell, damant, jeffery"], "marker": {"color": "#D55E00"}, "mode": "lines", "name": "8_river_whipped_steward_flood", "type": "scatter", "x": [17179569.304, 17408648.2, 17636587.4, 17864526.6], "y": [51, 59, 60, 17]}, {"hoverinfo": "text", "hovertext": ["<b>Topic 9</b><br>Words: imprisonment, suffer, security, prisoner, months", "<b>Topic 9</b><br>Words: bound, security, imprisonment, prisoner, imprisoned", "<b>Topic 9</b><br>Words: imprisoned, prisoner, months, imprisonment, month", "<b>Topic 9</b><br>Words: prisoner, jail, imprisoned, imprisonment, security", "<b>Topic 9</b><br>Words: prisoner, calendar, counterpleas, messrs, imprisonment"], "marker": {"color": "#0072B2"}, "mode": "lines", "name": "9_imprisonment_suffer_prisoner_security", "type": "scatter", "x": [17179569.304, 17408648.2, 17636587.4, 17864526.6, 18092465.8], "y": [47, 2, 53, 81, 3]}, {"hoverinfo": "text", "hovertext": ["<b>Topic  ...
